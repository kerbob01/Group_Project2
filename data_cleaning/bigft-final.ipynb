# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from config import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df=pd.read_csv("bigfoot.csv")
df
# Out:
#                                                observed  \
# 0      The article below, titled "The Wild Man - Wha...
# 1     OBSERVED: My great aunt, Ida Jones told me tha...
# 2                                                   NaN
# 3     Because of today's report of a Bigfoot Body, m...
# 4     The following was sent as a letter from a woma...
# ...                                                 ...
# 4128  Witness received a text message from a friend ...
# 4129  My father and I went to Loew Lake because I ha...
# 4130  It was the second weekend in September 2018, m...
# 4131  i want to start this off by saying, I don't kn...
# 4132  My friend and I rode snowmobiles about 8 miles...
#
#                                        location_details             county  \
# 0                                                   NaN  Stanislaus County
# 1     LOCATION: Carroll Co. Tennessee, in the south-...     Carroll County
# ...

# %%
df1=df[df['latitude'].isnull()]
df1
# Out:
#                                                observed  \
# 1     OBSERVED: My great aunt, Ida Jones told me tha...
# 4     The following was sent as a letter from a woma...
# 6     When I was just a small boy, my mother and fat...
# 11    This report has incidents going back 70 years ...
# 16    Shortly after the Reader's Digest article whic...
# ...                                                 ...
# 4030  On July 21st this year I was cutting grass at ...
# 4031  Aug 2016, my wife (then just friend) and I wer...
# 4049  My name is  T.W. and I live in Arkansas. Befor...
# 4064  At 3:30 am on July 1 2017. I was delivering ne...
# 4071  November 24, 2017 Two of us were coyote huntin...
#
#                                        location_details           county  \
# 1     LOCATION: Carroll Co. Tennessee, in the south-...   Carroll County
# 4     Walden is in a high mountain basin known as No...   Jackson County
# ...

# %%
df2=df[df['latitude'].notnull()]
df2
# Out:
#                                                observed  \
# 0      The article below, titled "The Wild Man - Wha...
# 2                                                   NaN
# 3     Because of today's report of a Bigfoot Body, m...
# 5     This is the second time I have listed this rep...
# 7                                                   NaN
# ...                                                 ...
# 4128  Witness received a text message from a friend ...
# 4129  My father and I went to Loew Lake because I ha...
# 4130  It was the second weekend in September 2018, m...
# 4131  i want to start this off by saying, I don't kn...
# 4132  My friend and I rode snowmobiles about 8 miles...
#
#                                        location_details             county  \
# 0                                                   NaN  Stanislaus County
# 2                                                   NaN  Clearfield County
# ...

# %%
#configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?address=Mason+County+Washington&key=AIzaSyA-ID1L5POajfL01AYW2ZHTmER2A5mJT4M')

geo_data=requests.get(target_url).json()
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Mason County",
#                     "short_name": "Mason County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Washington",
#                     "short_name": "WA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Mason County, WA, USA",
# ...

# %%
df1.loc[0:,'location']=df1['county'].astype(str)+'+'+df1['state'].astype(str)
df1.loc[0:,'lat'] = ""
df1.loc[0:,'lng'] = ""
#Y=df['Y']
#X=df['X']
#hotel_df['address'] = ""
#types_df['price_level'] = ""
#types_df['rating'] = ""
df1
# Out:
# C:\Users\fkari\Anaconda3\lib\site-packages\pandas\core\indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\fkari\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                                                observed  \
# 1     OBSERVED: My great aunt, Ida Jones told me tha...
# 4     The following was sent as a letter from a woma...
# ...

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json?"
params = {
    #"sensor":true/false
    #"key":"AIzaSyA-ID1L5POajfL01AYW2ZHTmER2A5mJT4M"
    "key":g_key
}
# use iterrows to iterate through pandas dataframe
for index,row in df1.iterrows():

    # get coordinates type from df!!!!
    geo_loc = row['location']

#     # add location to params dict
    params['address'] =geo_loc
    #print(params)
#     # assemble url and make API request
    #print(f"Retrieving Results for Index {index}: { zip_loc}.")
    response = requests.get(base_url,params=params).json()
    # extract results
    results = response['results']
    #print(results)
    try:
        #print(f"Closest hotel in {city_name}  is {results[0]['name']}.")
        
        df1.loc[index,'lat'] = results[0]["geometry"]["location"]["lat"]
        df1.loc[index,'lng'] = results[0]["geometry"]["location"]["lng"]

        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# %%
df1
# Out:
#                                                observed  \
# 1     OBSERVED: My great aunt, Ida Jones told me tha...
# 4     The following was sent as a letter from a woma...
# 6     When I was just a small boy, my mother and fat...
# 11    This report has incidents going back 70 years ...
# 16    Shortly after the Reader's Digest article whic...
# ...                                                 ...
# 4030  On July 21st this year I was cutting grass at ...
# 4031  Aug 2016, my wife (then just friend) and I wer...
# 4049  My name is  T.W. and I live in Arkansas. Befor...
# 4064  At 3:30 am on July 1 2017. I was delivering ne...
# 4071  November 24, 2017 Two of us were coyote huntin...
#
#                                        location_details           county  \
# 1     LOCATION: Carroll Co. Tennessee, in the south-...   Carroll County
# 4     Walden is in a high mountain basin known as No...   Jackson County
# ...

# %%
df1['latitude']=df1['latitude'].fillna(df1['lat'])
df1['longitude']=df1['longitude'].fillna(df1['lng'])
df1
# Out:
# C:\Users\fkari\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\fkari\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                observed  \
# 1     OBSERVED: My great aunt, Ida Jones told me tha...
# 4     The following was sent as a letter from a woma...
# ...

# %%
df1.drop(['location','lat','lng'],axis=1,inplace=True)
df1
# Out:
# C:\Users\fkari\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                                observed  \
# 1     OBSERVED: My great aunt, Ida Jones told me tha...
# 4     The following was sent as a letter from a woma...
# 6     When I was just a small boy, my mother and fat...
# 11    This report has incidents going back 70 years ...
# 16    Shortly after the Reader's Digest article whic...
# ...                                                 ...
# 4030  On July 21st this year I was cutting grass at ...
# 4031  Aug 2016, my wife (then just friend) and I wer...
# 4049  My name is  T.W. and I live in Arkansas. Befor...
# 4064  At 3:30 am on July 1 2017. I was delivering ne...
# ...

# %%
df_final=df2.append(df1)
df_final
# Out:
#                                                observed  \
# 0      The article below, titled "The Wild Man - Wha...
# 2                                                   NaN
# 3     Because of today's report of a Bigfoot Body, m...
# 5     This is the second time I have listed this rep...
# 7                                                   NaN
# ...                                                 ...
# 4030  On July 21st this year I was cutting grass at ...
# 4031  Aug 2016, my wife (then just friend) and I wer...
# 4049  My name is  T.W. and I live in Arkansas. Befor...
# 4064  At 3:30 am on July 1 2017. I was delivering ne...
# 4071  November 24, 2017 Two of us were coyote huntin...
#
#                                        location_details             county  \
# 0                                                   NaN  Stanislaus County
# 2                                                   NaN  Clearfield County
# ...

# %%
df_final.to_csv('restored_longlat_final.csv')
