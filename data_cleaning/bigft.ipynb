# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from config import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df=pd.read_csv("bigfoot01.csv")
df
# Out:
#               county          state  latitude  longitude  number
# 0     Carroll County      Tennessee       NaN        NaN    4543
# 1     Jackson County       Colorado       NaN        NaN    5641
# 2    Buchanan County       Missouri       NaN        NaN   24102
# 3        Gila County        Arizona       NaN        NaN    1606
# 4    Costilla County       Colorado       NaN        NaN    1353
# ..               ...            ...       ...        ...     ...
# 326  Randolph County  West Virginia       NaN        NaN   55583
# 327  Skamania County     Washington       NaN        NaN   62449
# 328    Conway County       Arkansas       NaN        NaN   58768
# 329     Lewis County     Washington       NaN        NaN   57789
# 330    Maries County       Missouri       NaN        NaN   59532
#
# [331 rows x 5 columns]

# %%
#configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?address=Mason+County+Washington&key=AIzaSyA-ID1L5POajfL01AYW2ZHTmER2A5mJT4M')

geo_data=requests.get(target_url).json()
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Mason County",
#                     "short_name": "Mason County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Washington",
#                     "short_name": "WA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Mason County, WA, USA",
# ...

# %%
df.loc[0:,'location']=df['county'].astype(str)+'+'+df['state'].astype(str)
df.loc[0:,'lat'] = ""
df.loc[0:,'lng'] = ""
#Y=df['Y']
#X=df['X']
#hotel_df['address'] = ""
#types_df['price_level'] = ""
#types_df['rating'] = ""
df
# Out:
#               county          state  latitude  longitude  number  \
# 0     Carroll County      Tennessee       NaN        NaN    4543
# 1     Jackson County       Colorado       NaN        NaN    5641
# 2    Buchanan County       Missouri       NaN        NaN   24102
# 3        Gila County        Arizona       NaN        NaN    1606
# 4    Costilla County       Colorado       NaN        NaN    1353
# ..               ...            ...       ...        ...     ...
# 326  Randolph County  West Virginia       NaN        NaN   55583
# 327  Skamania County     Washington       NaN        NaN   62449
# 328    Conway County       Arkansas       NaN        NaN   58768
# 329     Lewis County     Washington       NaN        NaN   57789
# 330    Maries County       Missouri       NaN        NaN   59532
#
#                           location lat lng
# 0         Carroll County+Tennessee
# 1          Jackson County+Colorado
# 2         Buchanan County+Missouri
# ...

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json?"
params = {
    #"sensor":true/false
    #"key":"AIzaSyA-ID1L5POajfL01AYW2ZHTmER2A5mJT4M"
    "key":g_key
}
# use iterrows to iterate through pandas dataframe
for index,row in df.iterrows():

    # get coordinates type from df!!!!
    geo_loc = row['location']

#     # add location to params dict
    params['address'] =geo_loc
    #print(params)
#     # assemble url and make API request
    #print(f"Retrieving Results for Index {index}: { zip_loc}.")
    response = requests.get(base_url,params=params).json()
    # extract results
    results = response['results']
    #print(results)
    try:
        #print(f"Closest hotel in {city_name}  is {results[0]['name']}.")
        
        df.loc[index,'lat'] = results[0]["geometry"]["location"]["lat"]
        df.loc[index,'lng'] = results[0]["geometry"]["location"]["lng"]
]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# %%
df=df[['number','county','state','lat','lng']]
df
# Out:
#      number           county          state      lat      lng
# 0      4543   Carroll County      Tennessee  35.9917 -88.4016
# 1      5641   Jackson County       Colorado  40.6819 -106.252
# 2     24102  Buchanan County       Missouri   39.635 -94.8106
# 3      1606      Gila County        Arizona  33.6371 -110.522
# 4      1353  Costilla County       Colorado   37.205 -105.501
# ..      ...              ...            ...      ...      ...
# 326   55583  Randolph County  West Virginia  38.8093 -80.0088
# 327   62449  Skamania County     Washington  45.9429 -121.896
# 328   58768    Conway County       Arkansas  35.2727 -92.6984
# 329   57789     Lewis County     Washington  46.6195 -122.455
# 330   59532    Maries County       Missouri  38.1739  -91.949
#
# [331 rows x 5 columns]

# %%
df.to_csv('restored_longlat.csv')
